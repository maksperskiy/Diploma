# %% [markdown]
# # 1.

# %%
# %pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python mediapipe sklearn matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\37533\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: opencv-python in c:\users\37533\anaconda3\lib\site-packages (4.5.5.62)
# Requirement already satisfied: mediapipe in c:\users\37533\anaconda3\lib\site-packages (0.8.9.1)
# Requirement already satisfied: sklearn in c:\users\37533\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: matplotlib in c:\users\37533\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: gast>=0.2.1 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: setuptools in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (2.8.0.dev2021122109)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\37533\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\37533\anaconda3\lib\site-packages (from mediapipe) (21.2.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\37533\anaconda3\lib\site-packages (from mediapipe) (4.5.5.62)
# Requirement already satisfied: scikit-learn in c:\users\37533\anaconda3\lib\site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\37533\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\37533\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\37533\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\37533\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\37533\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\37533\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\37533\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\37533\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\37533\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\37533\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\37533\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.6.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\37533\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.26.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\37533\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\37533\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\37533\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\37533\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\37533\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\37533\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\37533\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\37533\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\37533\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\37533\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\37533\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\37533\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\37533\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\37533\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\37533\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\37533\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2.

# %%
mp_holistic = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

# %%
def draw_landmarks(image, results):
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(
                image,
                hand_landmarks,
                mp_holistic.HAND_CONNECTIONS,
                mp_drawing_styles.get_default_hand_landmarks_style(),
                mp_drawing_styles.get_default_hand_connections_style())

# %%
def extract_keypoints(results):
    try:
        for idx, handLms in enumerate(results.multi_hand_landmarks):
            lh = np.array([[res.x, res.y, res.z] for res in
                           results.multi_hand_landmarks[idx].landmark]).flatten() \
                if results.multi_handedness[idx].classification[0].label == 'Left' else np.zeros(21 * 3)
            rh = np.array([[res.x, res.y, res.z] for res in
                           results.multi_hand_landmarks[idx].landmark]).flatten() \
                if results.multi_handedness[idx].classification[0].label == 'Right' else np.zeros(21 * 3)
        return np.concatenate([lh, rh])
    except:
        return np.concatenate([np.zeros(21 * 3), np.zeros(21 * 3)])

# %% [markdown]
# # 3.

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
actions = np.array([ 'up', 'down', 'left', 'right', 'ok', 'back'])

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'up': 0, 'down': 1, 'left': 2, 'right': 3, 'ok': 4, 'back': 5}

# %%
sequences = np.load("sequences.npy")
labels = np.load("labels.npy")

# %%
def interp_coords(x):
    coords = []
    for num,i in enumerate(x):
        if np.count_nonzero(i) != 0:
            coords.append([i,num])
    if not coords:
        return x
    result = []
    for i in range(126):
        result.append(np.interp(range(40),[e[1] for e in coords],[e[0][i] for e in coords]))
    return np.array(result).transpose()

# %%
sequences = np.array([interp_coords(e) for e in sequences])

# %%
np.array(sequences).shape
# Out:
# (180, 40, 126)

# %%
sequences[117,:,13]
# Out:
# array([0.72091711, 0.5262872 , 0.5289821 , 0.56253177, 0.5457027 ,
#        0.538248  , 0.5415135 , 0.54266447, 0.55735153, 0.55243224,
#        0.62361568, 0.62492919, 0.62459338, 0.62900215, 0.6250667 ,
#        0.63076842, 0.57194453, 0.64411694, 0.63277876, 0.63513589,
#        0.64984399, 0.66455209, 0.67294908, 0.71240586, 0.72480088,
#        0.72308987, 0.72365177, 0.726358  , 0.7267794 , 0.72064334,
#        0.72772491, 0.72834146, 0.72573471, 0.72409016, 0.71889502,
#        0.72127241, 0.72346354, 0.72411078, 0.72424698, 0.72339386])

# %%
np.array(labels).shape
# Out:
# (180,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (180, 40, 126)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
y_test.shape
# Out:
# (18, 6)

# %% [markdown]
# # 4.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(40,126)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, callbacks=[tb_callback])
# Out:
# Epoch 1/100
# 6/6 [==============================] - 8s 109ms/step - loss: 1.7829 - categorical_accuracy: 0.1728
# Epoch 2/100
# 6/6 [==============================] - 1s 122ms/step - loss: 1.7460 - categorical_accuracy: 0.2778
# Epoch 3/100
# 6/6 [==============================] - 1s 116ms/step - loss: 1.6570 - categorical_accuracy: 0.2407
# Epoch 4/100
# 6/6 [==============================] - 1s 111ms/step - loss: 1.5603 - categorical_accuracy: 0.2963
# Epoch 5/100
# 6/6 [==============================] - 1s 109ms/step - loss: 1.5202 - categorical_accuracy: 0.3148
# Epoch 6/100
# 6/6 [==============================] - 1s 107ms/step - loss: 1.9403 - categorical_accuracy: 0.4136
# Epoch 7/100
# 6/6 [==============================] - 1s 109ms/step - loss: 1.6135 - categorical_accuracy: 0.3889
# Epoch 8/100
# 6/6 [==============================] - 1s 109ms/step - loss: 1.6216 - categorical_accuracy: 0.3395
# Epoch 9/100
# 6/6 [==============================] - 1s 94ms/step - loss: 1.5447 - categorical_accuracy: 0.3210
# Epoch 10/100
# 6/6 [==============================] - 1s 132ms/step - loss: 1.6248 - categorical_accuracy: 0.3210
# Epoch 11/100
# 6/6 [==============================] - 1s 118ms/step - loss: 1.3468 - categorical_accuracy: 0.3889
# Epoch 12/100
# 6/6 [==============================] - 1s 104ms/step - loss: 1.3239 - categorical_accuracy: 0.5062
# Epoch 13/100
# 6/6 [==============================] - 1s 99ms/step - loss: 1.1450 - categorical_accuracy: 0.5556
# Epoch 14/100
# 6/6 [==============================] - 1s 107ms/step - loss: 1.3624 - categorical_accuracy: 0.3580
# Epoch 15/100
# 6/6 [==============================] - 1s 94ms/step - loss: 1.3541 - categorical_accuracy: 0.5432
# Epoch 16/100
# 6/6 [==============================] - 1s 106ms/step - loss: 1.2487 - categorical_accuracy: 0.4383
# Epoch 17/100
# 6/6 [==============================] - 1s 111ms/step - loss: 1.1846 - categorical_accuracy: 0.5185
# Epoch 18/100
# 6/6 [==============================] - 1s 100ms/step - loss: 1.2788 - categorical_accuracy: 0.5309
# Epoch 19/100
# 6/6 [==============================] - 1s 95ms/step - loss: 1.3639 - categorical_accuracy: 0.4321
# Epoch 20/100
# 6/6 [==============================] - 1s 90ms/step - loss: 1.1850 - categorical_accuracy: 0.5741
# Epoch 21/100
# 6/6 [==============================] - 1s 100ms/step - loss: 0.9888 - categorical_accuracy: 0.5802
# Epoch 22/100
# 6/6 [==============================] - 1s 88ms/step - loss: 0.8839 - categorical_accuracy: 0.6667
# Epoch 23/100
# Epoch 79/100
# 6/6 [==============================] - 1s 98ms/step - loss: 0.3114 - categorical_accuracy: 0.8951
# Epoch 80/100
# 6/6 [==============================] - 1s 100ms/step - loss: 0.2762 - categorical_accuracy: 0.8951
# Epoch 81/100
# 6/6 [==============================] - 1s 106ms/step - loss: 0.2136 - categorical_accuracy: 0.9444
# Epoch 82/100
# 6/6 [==============================] - 1s 106ms/step - loss: 0.1785 - categorical_accuracy: 0.9383
# Epoch 83/100
# 6/6 [==============================] - 1s 112ms/step - loss: 0.1705 - categorical_accuracy: 0.9444
# Epoch 84/100
# 6/6 [==============================] - 1s 100ms/step - loss: 0.1562 - categorical_accuracy: 0.9444
# Epoch 85/100
# 6/6 [==============================] - 1s 95ms/step - loss: 0.1456 - categorical_accuracy: 0.9506
# Epoch 86/100
# 6/6 [==============================] - 1s 110ms/step - loss: 0.0937 - categorical_accuracy: 0.9753
# Epoch 87/100
# 6/6 [==============================] - 1s 107ms/step - loss: 0.1003 - categorical_accuracy: 0.9753
# Epoch 88/100
# 6/6 [==============================] - 1s 109ms/step - loss: 0.0763 - categorical_accuracy: 0.9815
# Epoch 89/100
# 6/6 [==============================] - 1s 94ms/step - loss: 0.0650 - categorical_accuracy: 0.9815
# Epoch 90/100
# 6/6 [==============================] - 1s 99ms/step - loss: 0.0968 - categorical_accuracy: 0.9753
# Epoch 91/100
# 6/6 [==============================] - 1s 102ms/step - loss: 0.5909 - categorical_accuracy: 0.8827
# Epoch 92/100
# 6/6 [==============================] - 1s 105ms/step - loss: 0.2328 - categorical_accuracy: 0.9198
# Epoch 93/100
# 6/6 [==============================] - 1s 105ms/step - loss: 0.4259 - categorical_accuracy: 0.8704
# Epoch 94/100
# 6/6 [==============================] - 1s 103ms/step - loss: 0.2857 - categorical_accuracy: 0.9136
# Epoch 95/100
# 6/6 [==============================] - 1s 107ms/step - loss: 0.2754 - categorical_accuracy: 0.9012
# Epoch 96/100
# 6/6 [==============================] - 1s 109ms/step - loss: 0.2068 - categorical_accuracy: 0.9383
# Epoch 97/100
# 6/6 [==============================] - 1s 106ms/step - loss: 1.1556 - categorical_accuracy: 0.6852
# Epoch 98/100
# 6/6 [==============================] - 1s 103ms/step - loss: 0.7125 - categorical_accuracy: 0.7593
# Epoch 99/100
# 6/6 [==============================] - 1s 106ms/step - loss: 0.5755 - categorical_accuracy: 0.7593
# Epoch 100/100
# 6/6 [==============================] - 1s 105ms/step - loss: 0.4755 - categorical_accuracy: 0.7901

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 40, 64)            48896
#
#  lstm_1 (LSTM)               (None, 40, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 203,558
# Trainable params: 203,558
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 5.

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[4])]
# Out:
# 'down'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'down'

# %% [markdown]
# # 6.

# %%
model.save('action.h5')

# %%
del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 7.

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score, recall_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[14,  0],
#         [ 0,  4]],
#
#        [[15,  0],
#         [ 0,  3]],
#
#        [[15,  0],
#         [ 1,  2]],
#
#        [[15,  1],
#         [ 0,  2]],
#
#        [[15,  0],
#         [ 1,  2]],
#
#        [[14,  1],
#         [ 0,  3]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.8888888888888888

# %% [markdown]
# # 8.

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245), (16,217,245), (116,117,245), (116,217,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
with mp_holistic.Hands(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()

        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        draw_landmarks(image, results)
        
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-40:]
        
        if len(sequence) == 40:
            res = model.predict(np.expand_dims(interp_coords(sequence), axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# ...
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# down
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ok
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# up
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# back
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# left
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# right
